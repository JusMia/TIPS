# %%
#This program will help you to make summary of texts. 
#import pandas package to work with xlsx files
import pandas as pd
from pandas import DataFrame

# %%
# load file with text to summarize
stories1 = pd.read_excel("/content/drive/MyDrive/4000-Stories-31.05.xlsx", usecols=['title', 'story'])

# %%
#Install summarizer and useful packages
# !pip install -q bert-extractive-summarizer

# %%
# !pip install -q NLTK

# %%
# There is need to get proper version of Python, bert-extractive-summarizer and torch, otherwise summarizer would not work.
# !apt-get install  python3.5
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.5 is already the newest version (3.5.10-1+bionic2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !pip install spacy
# !pip install transformers # > 2.2.0
# !pip install neuralcoref

# !python -m spacy download en_core_web_md
# Out:
# ...
#      |████████████████████████████████| 96.4 MB 1.4 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
# !pip install -q transformers

# %%
# !pip install summarizer

# %%
from summarizer import Summarizer

# %%
# !pip install sentencepiece

# %%
# !pip install pytorch_pretrained_bert

# %%
# !pip install torch==1.6.0+cpu torchvision==0.7.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
pip install bert-extractive-summarizer==0.4.2

# %%
###Boarding-House Geometry
from summarizer import Summarizer
model = Summarizer()
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from summarizer import Summarizer
body2 = '''
"A Stag was chased by the hounds, and took refuge in a cave, where he hoped to be safe from his pursuers. Unfortunately the cave contained a Lion, to whom he fell an easy prey. ""Unhappy that I am,"" he cried, ""I am saved from the power of the dogs only to fall into the clutches of a Lion.""
Out of the frying-pan, into the fire."
'''
#Prepare summary of text with Summarizer, where ratio is percentage value of text lenght. It means that summary will be equal 30% of original text, max lenght is maximal lenght of 1 sentence in summary, 'use First' set as TRUE, means that first sentence from originall data will be used
result2 ={}
result = model(body2, ratio=0.30, max_length = 200, use_first = True) 
print(result)
# Out:
# "A Stag was chased by the hounds, and took refuge in a cave, where he hoped to be safe from his pursuers. Unfortunately the cave contained a Lion, to whom he fell an easy prey. ""

# %%
titles =[]
story= []
summ =[]

# %%
#make summarization for more than 1 story. 
result3 = {}

for a in range(74,78):
  body2 = stories1['story'][a]
  print('title:', stories1['title'][a])
  for j in range(0,5):
      result = model(body2, ratio=0.3, max_length = 200, use_first = False)
      result3[j] = result
      print(result)
      titles.append(stories1['title'][a])
      story.append(body2)
      summ.append(result3[j])
# Out:
# title: The Dog and the Bees
# As it is, you have driven me into a secure retreat; for I can snap you up as fast as you come in through the bung-hole.
# As it is, you have driven me into a secure retreat; for I can snap you up as fast as you come in through the bung-hole.
# As it is, you have driven me into a secure retreat; for I can snap you up as fast as you come in through the bung-hole.
# As it is, you have driven me into a secure retreat; for I can snap you up as fast as you come in through the bung-hole.
# As it is, you have driven me into a secure retreat; for I can snap you up as fast as you come in through the bung-hole.
# title: The Dog And His Masters Dinner
# A Dog had learned to carry his master's dinner to him every day. He was very faithful to his duty, though the smell of the good things in the basket tempted him.
# ...
